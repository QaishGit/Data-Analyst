# %%
print(1+1)
# Out:
# 2

# %%
'''Here we are learning about indentation
the print(age) after if condition is within if's block and print(1+1)
is outside if's block'''
age=32
if age>30:
    print(age)
print(1+1)
# Out:
# 32
# 2

# %%
##Variable assignment
##Kernel automatically knows the data type of the variable based
##on the value assigned to the variable
age=32
name="Cash"

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
##Indentation example
if True:
    print("Correct Indentation")
    if False:
        print("This won't print")
    print("This will print")
print("Outside of the if block")
# Out:
# Correct Indentation
# This will print
# Outside of the if block

# %%
##Python is case sensitive
name="cash"
Name="kash"

print(name)
print(Name)
# Out:
# cash
# kash
