# %%
## Integer datatype

age = 25
print(age)
print(type(age))
# Out:
# 25
# <class 'int'>

# %%
## Floating point number

height = 5.11
print(height)
print(type(height))
# Out:
# 5.11
# <class 'float'>

# %%
## String datatype

name = "Cash"
print(name)
print(type(name))
# Out:
# Cash
# <class 'str'>

# %%
## Boolean datatype

is_true = True
print(type(is_true))
# Out:
# <class 'bool'>

# %%
is_true = bool()
print(is_true)
# Out:
# False

# %%
a=10;b=10
type(a==b)
# Out:
# bool

# %%
result = "Hello" + str(5)
print(result)
# Out:
# Hello5
