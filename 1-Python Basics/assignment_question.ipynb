# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
user_input = input("Enter somethin: ")
print("User entered: ",user_input)
print(f"User entered: {user_input}")
# Out:
# User entered:  dfg
# User entered: dfg

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num = int(input("Enter a number"))
if num<0:
    print("Negative")

if num==0:
    print("Zero")

if num>0:
    print("Positive")
# Out:
# Positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
num1 = int(input())
num2 = int(input())
num3 = int(input())

if num1>num2 and num1>num3:
    print("Largest number: ", num1)

if num2>num1 and num2>num3:
    print("Largest number: ", num2)

if num3>num1 and num3>num2:
    print("Largest number: ", num3)
# Out:
# Largest number:  3

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
num = int(input("Enter a number for factorial"))
fact = 1
for i in range(1,num+1):
    fact = fact*i

print(f"Factorial of {num} for code 1: {fact}")

##OR

fact1 = 1
for i in range(num, 0, -1):
    fact1 = fact1*i

print(f"Factorial of {num} for code 2: {fact1}")
# Out:
# Factorial of 5 for code 1: 120
# Factorial of 5 for code 2: 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
name = "Cash"  ##String
age = 25       ##Integer
height = 6.0   ##Float 
is_true = True ##Bool

print(name, type(name))
print(age, type(age))
print(height, type(height))
print(is_true, type(is_true))
# Out:
# Cash <class 'str'>
# 25 <class 'int'>
# 6.0 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
num1 = float(input())
num2 = float(input())

print(f"Numbers before swapping: num1 = {num1} and num2 = {num2}")

temp = 0 
temp = num1
num1 = num2
num2 = temp

print(f"Numbers after swapping: num1 = {num1} and num2 = {num2}")
# Out:
# Numbers before swapping: num1 = 4.0 and num2 = 5.0
# Numbers after swapping: num1 = 5.0 and num2 = 4.0

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
celsius = float(input("Enter temperature in celcius"))
fahrenheit = (celsius*(9/5))+32
print(f"{celsius} C = {fahrenheit} F")
# Out:
# 0.0 C = 32.0 F

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
str1 = input("Enter something")
str2 = input("Enter something")
print(str1 +" "+ str2)
# Out:
# Hello Cash

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
var = 10.5
if isinstance(var, float):
    print(f"{var} is a float")
else:   
    print(f"{var} is not a float")
# Out:
# 10.5 is a float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
num1 = float(input("Enter a number"))
num2 = float(input("Enter a number"))

add_result = num1+num2
sub_result = num1-num2
mult_result = num1*num2
div_result = num1/num2

print("Addition: ", add_result)
print("Subtraction: ", sub_result)
print(f"Multiplication: {mult_result}")
print(f"Division: {div_result}")
# Out:
# Addition:  15.0
# Subtraction:  5.0
# Multiplication: 50.0
# Division: 2.0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
a = 10
b = 5

print(f"{a}=={b}: {a==b}")
print(f"{a}!={b}: {a!=b}")
print(f"{a}>{b}: {a>b}")
print(f"{a}<{b}: {a<b}")
# Out:
# 10==5: False
# 10!=5: True
# 10>5: True
# 10<5: False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a = True
b = False

##AND
print(f"{a} AND {b} = {a and b}")
print(f"{a} OR {b} = {a or b}")
print(f"NOT of {a} = {not a}")
# Out:
# True AND False = False
# True OR False = True
# NOT of True = False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
num = float(input("Enter a number: "))
square = num**2
print(f"Square of {num} = {square}")
# Out:
# Square of 5.0 = 25.0

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = int(input("Enter a number: "))
if (num==1 or num==0 or num<0):
    print("Enter a poitive number greater than 1")
elif (num%2==0):
    print(f"{num} is Even")
else: 
    print(f"{num} is Odd")
# Out:
# Enter a poitive number greater than 1

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
'''sum_upto = int(input("Enter a number upto which you want sum: "))
sum = 0
for i in range(1, sum_upto+1):
    sum = sum+i

print(f"Sum of first {sum_upto} natural numbers = {sum}")'''

n = int(input("Enter a number: "))
sum_n = (n * (n + 1)) // 2
print(f"The sum of the first {n} natural numbers is {sum_n}")
# Out:
# The sum of the first 10 natural numbers is 55

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
year = int(input("Enter a year"))

if (year%4==0):
    print(f"The year {year} is a Leap year")
else:
    print(f"The year {year} is not a Leap year")
# Out:
# The year 1990 is not a Leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
str = input("Enter a string")
reversed_str = str[::-1]
print(f'The reverse of string "{str}" is "{reversed_str}"')
# Out:
# The reverse of string "cash" is "hsac"

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
str = input("Enter a string")
if str[::-1]==str:
    print(f'The string "{str}" is a palindrome')
else:
    print(f'The string "{str}" is not a palindrome')
# Out:
# The string "oyo" is a palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
numbers = [int(x) for x in input("Enter numbers separated by space").split()]
print(f"List eneterd: {numbers}")
numbers.sort()
print(f"Sorted list: {numbers}")
# Out:
# List eneterd: [2, 4, 3, 8, 6, 9, 0]
# Sorted list: [0, 2, 3, 4, 6, 8, 9]
