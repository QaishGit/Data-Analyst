# %%
import array

arr = array.array('i', [1, 2, 3, 4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math

print(math.sqrt(36))
print(math.pi)
# Out:
# 6.0
# 3.141592653589793

# %%
import random

print(random.randint(1, 10))
print(random.choice(['a', 2, "mango", 4, 5.8]))
# Out:
# 10
# mango

# %% [markdown]
# File and Directory Access

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\ermoh\OneDrive\Desktop\Data-Analyst\Python\5-Modules

# %%
## Creating a folder in current directory

os.mkdir('test_dir')

# %%
## High level operations on files and collection of files

import shutil

shutil.copyfile('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization

import json

data = {'name': 'cash', 'age': 25}
json_str = json.dumps(data)
parsed_data = json.loads(json_str)

print(json_str)
print(type(json_str))
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "cash", "age": 25}
# <class 'str'>
# {'name': 'cash', 'age': 25}
# <class 'dict'>

# %%
## CSV

import csv

with open('sample.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['cash', 25])

with open('sample.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['cash', '25']

# %%
##Datetime

from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2026-07-30 22:37:20.074666
# 2026-07-29 22:37:20.074666

# %%
## time
import time

print(time.time())
time.sleep(5)
print(time.time())
# Out:
# 1785431709.7370641
# 1785431714.739291

# %%
## Regular expression

import re

pattern = r'\d+'
text = "I ahve 20 apples"

match = re.search(pattern, text)
print(match.group())
# Out:
# 20
