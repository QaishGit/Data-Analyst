# %% [markdown]
# # Module: Pandas Assignments
# ## Lesson: Pandas
# ### Assignment 1: DataFrame Creation and Indexing
#
# 1. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Set the index to be the first column.
# 2. Create a Pandas DataFrame with columns 'A', 'B', 'C' and index 'X', 'Y', 'Z'. Fill the DataFrame with random integers and access the element at row 'Y' and column 'B'.
#
# ### Assignment 2: DataFrame Operations
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Add a new column that is the product of the first two columns.
# 2. Create a Pandas DataFrame with 3 columns and 4 rows filled with random integers. Compute the row-wise and column-wise sum.
#
# ### Assignment 3: Data Cleaning
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Introduce some NaN values. Fill the NaN values with the mean of the respective columns.
# 2. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Introduce some NaN values. Drop the rows with any NaN values.
#
# ### Assignment 4: Data Aggregation
#
# 1. Create a Pandas DataFrame with 2 columns: 'Category' and 'Value'. Fill the 'Category' column with random categories ('A', 'B', 'C') and the 'Value' column with random integers. Group the DataFrame by 'Category' and compute the sum and mean of 'Value' for each category.
# 2. Create a Pandas DataFrame with 3 columns: 'Product', 'Category', and 'Sales'. Fill the DataFrame with random data. Group the DataFrame by 'Category' and compute the total sales for each category.
#
# ### Assignment 5: Merging DataFrames
#
# 1. Create two Pandas DataFrames with a common column. Merge the DataFrames using the common column.
# 2. Create two Pandas DataFrames with different columns. Concatenate the DataFrames along the rows and along the columns.
#
# ### Assignment 6: Time Series Analysis
#
# 1. Create a Pandas DataFrame with a datetime index and one column filled with random integers. Resample the DataFrame to compute the monthly mean of the values.
# 2. Create a Pandas DataFrame with a datetime index ranging from '2021-01-01' to '2021-12-31' and one column filled with random integers. Compute the rolling mean with a window of 7 days.
#
# ### Assignment 7: MultiIndex DataFrame
#
# 1. Create a Pandas DataFrame with a MultiIndex (hierarchical index). Perform some basic indexing and slicing operations on the MultiIndex DataFrame.
# 2. Create a Pandas DataFrame with MultiIndex consisting of 'Category' and 'SubCategory'. Fill the DataFrame with random data and compute the sum of values for each 'Category' and 'SubCategory'.
#
# ### Assignment 8: Pivot Tables
#
# 1. Create a Pandas DataFrame with columns 'Date', 'Category', and 'Value'. Create a pivot table to compute the sum of 'Value' for each 'Category' by 'Date'.
# 2. Create a Pandas DataFrame with columns 'Year', 'Quarter', and 'Revenue'. Create a pivot table to compute the mean 'Revenue' for each 'Quarter' by 'Year'.
#
# ### Assignment 9: Applying Functions
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Apply a function that doubles the values of the DataFrame.
# 2. Create a Pandas DataFrame with 3 columns and 6 rows filled with random integers. Apply a lambda function to create a new column that is the sum of the existing columns.
#
# ### Assignment 10: Working with Text Data
#
# 1. Create a Pandas Series with 5 random text strings. Convert all the strings to uppercase.
# 2. Create a Pandas Series with 5 random text strings. Extract the first three characters of each string.

# %% [markdown]
# Assignment 1

# %%
## 1
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randint(1, 101, size=(6, 4)), columns=['A', 'B', 'C', 'D'])
print("Original DataFrame:")
print(df)

df.set_index('A', inplace=True)
print("\nModified DataFrame with changed index:")
print(df)
# Out:
# Original DataFrame:
#      A   B   C   D
# 0   90  73  60  68
# 1   29  12  12  86
# 2  100  25  65  24
# 3   93  80  26  89
# 4   59  27  62  95
# 5   80  65   5  97
#
# Modified DataFrame with changed index:
#       B   C   D
# A
# 90   73  60  68
# 29   12  12  86
# 100  25  65  24
# 93   80  26  89
# 59   27  62  95
# 80   65   5  97

# %%
## 2

df = pd.DataFrame(np.random.randint(1, 10, size=(3, 3)), index=['X', 'Y', 'Z'], columns=['A', 'B', 'c'])
print("Original DataFrame:")
print(df)

print("\nElement at row 'Y' and column 'B': ", df.at['Y', 'B']) 
print("\nElement at row 'Y' and column 'B': ", df.loc['Y']['B']) # OR df.loc['Y', 'B']
# Out:
# Original DataFrame:
#    A  B  c
# X  2  7  7
# Y  7  6  3
# Z  8  5  3
#
# Element at row 'Y' and column 'B':  6
#
# Element at row 'Y' and column 'B':  6

# %% [markdown]
# Assignment 2

# %%
## 1

df = pd.DataFrame(np.random.randint(1, 10, size=(5, 3)), columns=['A', 'B', 'C'])
print("Original DataFrame:")
print(df)

df['AxB'] = df['A'] * df['B']
print("\nModified DataFrame:")
print(df)
# Out:
# Original DataFrame:
#    A  B  C
# 0  4  8  7
# 1  7  4  5
# 2  8  3  2
# 3  6  2  4
# 4  1  7  7
#
# Modified DataFrame:
#    A  B  C  AxB
# 0  4  8  7   32
# 1  7  4  5   28
# 2  8  3  2   24
# 3  6  2  4   12
# 4  1  7  7    7

# %%
## 2
df = pd.DataFrame(np.random.randint(1, 10, size=(4, 3)), columns=['A', 'B', 'C'])
print("Original DataFrame:")
print(df)

row_sum = np.sum(df, axis=1)
col_sum = np.sum(df, axis=0)

print("\nRow sum:") 
print(row_sum)
print("\nColumn sum:") 
print(col_sum)
# Out:
# Original DataFrame:
#    A  B  C
# 0  5  7  2
# 1  1  3  2
# 2  1  7  8
# 3  2  5  9
#
# Row sum:
# 0    14
# 1     6
# 2    16
# 3    16
# dtype: int64
#
# Column sum:
# A     9
# B    22
# C    21
# dtype: int64

# %% [markdown]
# Assignment 3

# %%
## 1
df = pd.DataFrame(np.random.randint(1, 100, size=(4, 3)), columns=['A', 'B', 'C'])
print("Original DataFrame:")
print(df)

df.iat[0, 1] = np.nan
df.iat[1, 2] = np.nan
df.iloc[2, 0] = np.nan
print("\nDataFarem with NaN values")
print(df)

df.fillna(df.mean(), inplace=True)
print("\nModified DataFrame with filled missing values with mean:")
print(df)
# Out:
# Original DataFrame:
#     A   B   C
# 0  69  85  44
# 1  33  98  92
# 2  97  68  41
# 3  31  80  59
#
# DataFarem with NaN values
#       A     B     C
# 0  69.0   NaN  44.0
# 1  33.0  98.0   NaN
# 2   NaN  68.0  41.0
# 3  31.0  80.0  59.0
#
# Modified DataFrame with filled missing values with mean:
#            A     B     C
# 0  69.000000  82.0  44.0
# 1  33.000000  98.0  48.0
# 2  44.333333  68.0  41.0
# 3  31.000000  80.0  59.0

# %%
## 2

df = pd.DataFrame(np.random.randint(1, 100, size=(6, 4)), columns=['A', 'B', 'C', 'D'])
print("Original DataFrame:")
print(df)

df.iat[0, 3] = np.nan
df.iloc[3, 2] = np.nan
df.iat[5, 1] = np.nan
df.iloc[1, 0] = np.nan
print("\nDataFrame with missing values:")
print(df)

df.dropna(inplace=True)
print("\nModified DataFrame:")
print(df)
# Out:
# Original DataFrame:
#     A   B   C   D
# 0  36  14  45  17
# 1  60   3  35  24
# 2   3  63  97  33
# 3  54  45  92  81
# 4  67  39  46  69
# 5  17  16  19  70
#
# DataFrame with missing values:
#       A     B     C     D
# 0  36.0  14.0  45.0   NaN
# 1   NaN   3.0  35.0  24.0
# 2   3.0  63.0  97.0  33.0
# 3  54.0  45.0   NaN  81.0
# 4  67.0  39.0  46.0  69.0
# 5  17.0   NaN  19.0  70.0
#
# Modified DataFrame:
#       A     B     C     D
# 2   3.0  63.0  97.0  33.0
# 4  67.0  39.0  46.0  69.0

# %% [markdown]
# Assignment 4

# %%
## 1

df = pd.DataFrame({'Category': np.random.choice(['A', 'B', 'C'], size=10),
                   'Value': np.random.randint(1, 100, size=10)})
print("Original DataFrame:")
print(df)

grouped = df.groupby('Category')['Value'].agg(['sum', 'mean'])
print("\nGrouped DataFrame:")
print(grouped)
# Out:
# Original DataFrame:
#   Category  Value
# 0        B      4
# 1        C     86
# 2        C     29
# 3        C     78
# 4        C     51
# 5        C     88
# 6        A     70
# 7        C     31
# 8        B     62
# 9        B     88
#
# Grouped DataFrame:
#           sum       mean
# Category
# A          70  70.000000
# B         154  51.333333
# C         363  60.500000

# %%
## 2

df = pd.DataFrame({'Product': np.random.choice(['Product1', 'Product2', 'Product3'], size=10),
                   'Category': np.random.choice(['A', 'B', 'C'], size=10),
                   'Sales': np.random.randint(1, 100, size=10)})
print("Original DataFrame:")
print(df)

grouped_category = df.groupby('Category')['Sales'].sum()
print("\nGrouped DataFrame:")
print(grouped_category)
# Out:
# Original DataFrame:
#     Product Category  Sales
# 0  Product3        C     57
# 1  Product2        B     99
# 2  Product2        A     36
# 3  Product2        A     65
# 4  Product1        A     81
# 5  Product1        C     36
# 6  Product3        C     62
# 7  Product2        C     82
# 8  Product3        A     52
# 9  Product1        B     70
#
# Grouped DataFrame:
# Category
# A    234
# B    169
# C    237
# Name: Sales, dtype: int32

# %% [markdown]
# Assignment 5

# %%
## 1

df1 = pd.DataFrame({'Key': ['A', 'B', 'C', 'D'], 'Value1': np.random.randint(1, 100, size=4)})
df2 = pd.DataFrame({'Key': ['A', 'B', 'D', 'E'], 'Value2': np.random.randint(1, 100, size=4)})
print("DataFrame 1:")
print(df1)
print("\nDataFrame 2:")
print(df2)

merge_df = pd.merge(df1, df2, on='Key', how='inner')
print("\nInner join of 2 DataFrames:")
print(merge_df)
# Out:
# DataFrame 1:
#   Key  Value1
# 0   A      32
# 1   B      25
# 2   C      54
# 3   D      46
#
# DataFrame 2:
#   Key  Value2
# 0   A      42
# 1   B      30
# 2   D      21
# 3   E      84
#
# Inner join of 2 DataFrames:
#   Key  Value1  Value2
# 0   A      32      42
# 1   B      25      30
# 2   D      46      21

# %%
## 2

df1 = pd.DataFrame({'A': np.random.randint(1, 100, size=3), 'B': np.random.randint(1, 100, size=3)})
df2 = pd.DataFrame({'C': np.random.randint(1, 100, size=3), 'D': np.random.randint(1, 100, size=3)})
print("First DataFrame:")
print(df1)
print("\nSeconda DataFrame:")
print(df2)

concat_rows = pd.concat([df1, df2], axis=0)
print("\nRow-wise cocatination:")
print(concat_rows)

concat_columns = pd.concat([df1, df2], axis=1)
print("\nColumn-wise Concatination:")
print(concat_columns)
# Out:
# First DataFrame:
#     A   B
# 0  73  99
# 1  66  48
# 2  26  96
#
# Seconda DataFrame:
#     C   D
# 0  81  53
# 1  63  37
# 2   1  70
#
# Row-wise cocatination:
#       A     B     C     D
# 0  73.0  99.0   NaN   NaN
# 1  66.0  48.0   NaN   NaN
# 2  26.0  96.0   NaN   NaN
# 0   NaN   NaN  81.0  53.0
# 1   NaN   NaN  63.0  37.0
# 2   NaN   NaN   1.0  70.0
#
# Column-wise Concatination:
#     A   B   C   D
# 0  73  99  81  53
# 1  66  48  63  37
# 2  26  96   1  70

# %% [markdown]
# Assignment 6

# %%
## 1

date_rng = pd.date_range(start='2022-01-01', end='2022-12-31', freq='D')
df = pd.DataFrame(date_rng, columns=['Dates'])
df['Data'] = np.random.randint(0, 100, size=len(date_rng))
print("original DataFrame:")
print(df) 

df.set_index(['Dates'], inplace=True)
print("\nModified DataFrame:")
print(df)

monthly_mean = df.resample('ME').mean()
print("\nMonth-wise Mean:")
print(monthly_mean)
# Out:
# original DataFrame:
#          Dates  Data
# 0   2022-01-01    26
# 1   2022-01-02    89
# 2   2022-01-03    46
# 3   2022-01-04    90
# 4   2022-01-05    46
# ..         ...   ...
# 360 2022-12-27    94
# 361 2022-12-28    27
# 362 2022-12-29     1
# 363 2022-12-30    26
# 364 2022-12-31    90
#
# [365 rows x 2 columns]
#
# Modified DataFrame:
#             Data
# Dates
# 2022-01-01    26
# 2022-01-02    89
# 2022-01-03    46
# 2022-01-04    90
# 2022-01-05    46
# ...          ...
# 2022-12-27    94
# 2022-12-28    27
# 2022-12-29     1
# 2022-12-30    26
# 2022-12-31    90
#
# [365 rows x 1 columns]
#
# Month-wise Mean:
#                  Data
# Dates
# 2022-01-31  51.516129
# 2022-02-28  40.642857
# 2022-03-31  45.967742
# 2022-04-30  49.933333
# 2022-05-31  47.516129
# 2022-06-30  47.533333
# 2022-07-31  47.774194
# 2022-08-31  51.935484
# 2022-09-30  50.533333
# 2022-10-31  44.741935
# 2022-11-30  63.433333
# 2022-12-31  45.354839

# %%
## 2

date_rng = pd.date_range(start='2021-01-01', end='2021-12-31', freq='D')
df = pd.DataFrame(date_rng, columns=['Dates'])
df['Data'] = np.random.randint(0, 100, size=len(date_rng))
print("Original DataFrame:")
print(df)

df.set_index('Dates', inplace=True)

rolling_mean = df.rolling(window=7).mean()
print("\nRolling Mean:")
print(rolling_mean)
# Out:
# Original DataFrame:
#          Dates  Data
# 0   2021-01-01    74
# 1   2021-01-02    16
# 2   2021-01-03    65
# 3   2021-01-04    66
# 4   2021-01-05    41
# ..         ...   ...
# 360 2021-12-27    54
# 361 2021-12-28    47
# 362 2021-12-29    77
# 363 2021-12-30    43
# 364 2021-12-31    82
#
# [365 rows x 2 columns]
#
# Rolling Mean:
#                  Data
# Dates
# 2021-01-01        NaN
# 2021-01-02        NaN
# 2021-01-03        NaN
# 2021-01-04        NaN
# 2021-01-05        NaN
# ...               ...
# 2021-12-27  40.857143
# 2021-12-28  46.000000
# 2021-12-29  56.571429
# 2021-12-30  49.571429
# 2021-12-31  52.571429
#
# [365 rows x 1 columns]

# %% [markdown]
# Assignment 7

# %%
## 1

arrays = [['A', 'A', 'B', 'B'], ['one', 'two', 'one', 'two']]
index = pd.MultiIndex.from_arrays(arrays, names=('Category', 'Sub-category'))
df = pd.DataFrame(np.random.randint(1, 100, size=(4, 2)), index=index, columns=['Val1', 'Val2'])
print("Original DataFrame:")
print(df)

print("\nVal1 items in A in one:", df.loc[('A', 'one'), 'Val1'])

print("\nVal2 in both sub-categories in B:")
print(df.loc['B'])

print("\nVal1 of sub-category one of A and Val2 of sub-category two of b:")
print(df.loc[[('A', 'one', 'Val1'), ('B', 'two', 'Val2')]])
# Out:
# Original DataFrame:
#                        Val1  Val2
# Category Sub-category
# A        one             58    28
#          two             94    92
# B        one             19    89
#          two             86    72
#
# Val1 items in A in one: 58
#
# Val2 in both sub-categories in B:
#               Val1  Val2
# Sub-category
# one             19    89
# two             86    72
#
# Val1 of sub-category one of A and Val2 of sub-category two of b:
#                        Val1  Val2
# Category Sub-category
# A        one             58    28
# B        two             86    72

# %%
## 2

array = [['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B'], ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']]
index = pd.MultiIndex.from_arrays(array, names=['Category', 'Sub-Category'])
df = pd.DataFrame(np.random.randint(1, 100, size=(8, 1)), index=index, columns=['Value'])
print("Original DataFrame:")
print(df)

grouped_sum = df.groupby(['Category', 'Sub-Category'])['Value'].sum()
print("\nGroup-wise sum of values of category A and B:")
print(grouped_sum)
# Out:
# Original DataFrame:
#                        Value
# Category Sub-Category
# A        one              14
#          two               9
#          one              73
#          two              20
# B        one              32
#          two              67
#          one              93
#          two              59
#
# Group-wise sum of values of category A and B:
# Category  Sub-Category
# A         one              87
#           two              29
# B         one             125
#           two             126
# Name: Value, dtype: int32

# %% [markdown]
# Assignment 8

# %%
## 1

# %%
## 2

# %% [markdown]
# Assignment 9

# %%
## 1

df = pd.DataFrame(np.random.randint(1, 100, size=(5, 3)), columns=['Value1', 'Value2', 'Value3'])
print("Original DataFrame:")
print(df)

df_doubled = df.map(lambda x: x*2,)
print("\nModified DataFrame with each value doubled:")
print(df_doubled)
# Out:
# Original DataFrame:
#    Value1  Value2  Value3
# 0      44      23      23
# 1      31      97      76
# 2      56      13      74
# 3      61      78      99
# 4       5      95      44
#
# Modified DataFrame with each value doubled:
#    Value1  Value2  Value3
# 0      88      46      46
# 1      62     194     152
# 2     112      26     148
# 3     122     156     198
# 4      10     190      88

# %%
## 2

df = pd.DataFrame(np.random.randint(1, 10, size=(6, 3)), columns=['A', 'B', 'C'])
print("Original DataFrame:")
print(df)

# df['Columns_sum'] = df.apply(lambda row: row.sum(), axis=1)
# print("\nModified DataFrame:")
# print(df)

df['sum'] = df.sum(axis=1)
print("\nAnother method:")
print(df)
# Out:
# Original DataFrame:
#    A  B  C
# 0  1  6  6
# 1  5  5  1
# 2  4  7  7
# 3  1  5  4
# 4  1  2  2
# 5  2  4  6
#
# Another method:
#    A  B  C  sum
# 0  1  6  6   13
# 1  5  5  1   11
# 2  4  7  7   18
# 3  1  5  4   10
# 4  1  2  2    5
# 5  2  4  6   12
