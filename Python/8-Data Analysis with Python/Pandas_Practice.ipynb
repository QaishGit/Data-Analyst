# %% [markdown]
# ## Practicing Pandas

# %% [markdown]
# Question 1:

# %%
## Answer
import pandas as pd

df = pd.DataFrame({
    'Name': ['Jack', 'Rahul', 'Sara', 'John', 'Rohan'],
    'Age': [21, 22, 20, 23, 21],
    'Marks': [85, 72, 91, 68, 88],
   'City': ['Delhi', 'Mumbai', 'Delhi', 'Pune', 'Mumbai']
})
print("DataFrame:")
print(df)

print("\nFirst three rows:")
print(df.head(3))

print()
print(df[['Name', 'Marks']]) ## Double square brackets because we are selecting multiple columns

print(f"\nAnerage marks: {df['Marks'].mean()}")

print(f"\nStudent with highest marks: {df.loc[df['Marks'].idxmax()]}")

print()
print(df[df['Marks']>80])
# Out:
# DataFrame:
#     Name  Age  Marks    City
# 0   Jack   21     85   Delhi
# 1  Rahul   22     72  Mumbai
# 2   Sara   20     91   Delhi
# 3   John   23     68    Pune
# 4  Rohan   21     88  Mumbai
#
# First three rows:
#     Name  Age  Marks    City
# 0   Jack   21     85   Delhi
# 1  Rahul   22     72  Mumbai
# 2   Sara   20     91   Delhi
#
#     Name  Marks
# 0   Jack     85
# 1  Rahul     72
# 2   Sara     91
# 3   John     68
# 4  Rohan     88
#
# Anerage marks: 80.8
#
# Student with highest marks: Name      Sara
# Age         20
# Marks       91
# City     Delhi
# Name: 2, dtype: object
#
#     Name  Age  Marks    City
# 0   Jack   21     85   Delhi
# 2   Sara   20     91   Delhi
# 4  Rohan   21     88  Mumbai
