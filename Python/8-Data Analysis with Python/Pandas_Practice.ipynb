# %% [markdown]
# ## Practicing Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Basics

# %% [markdown]
# Question 1:

# %%
## Answer

df = pd.DataFrame({
    'Name': ['Jack', 'Rahul', 'Sara', 'John', 'Rohan'],
    'Age': [21, 22, 20, 23, 21],
    'Marks': [85, 72, 91, 68, 88],
   'City': ['Delhi', 'Mumbai', 'Delhi', 'Pune', 'Mumbai']
})
print("DataFrame:")
print(df)

print("\nFirst three rows:")
print(df.head(3))

print()
print(df[['Name', 'Marks']]) ## Double square brackets because we are selecting multiple columns

print(f"\nAnerage marks: {df['Marks'].mean()}")

print("\nStudent with highest marks:")
print(df.loc[df['Marks'].idxmax()])

print()
print(df[df['Marks']>80])
# Out:
# DataFrame:
#     Name  Age  Marks    City
# 0   Jack   21     85   Delhi
# 1  Rahul   22     72  Mumbai
# 2   Sara   20     91   Delhi
# 3   John   23     68    Pune
# 4  Rohan   21     88  Mumbai
#
# First three rows:
#     Name  Age  Marks    City
# 0   Jack   21     85   Delhi
# 1  Rahul   22     72  Mumbai
# 2   Sara   20     91   Delhi
#
#     Name  Marks
# 0   Jack     85
# 1  Rahul     72
# 2   Sara     91
# 3   John     68
# 4  Rohan     88
#
# Anerage marks: 80.8
#
# Student with highest marks:
# Name      Sara
# Age         20
# Marks       91
# City     Delhi
# Name: 2, dtype: object
#
#     Name  Age  Marks    City
# 0   Jack   21     85   Delhi
# 2   Sara   20     91   Delhi
# 4  Rohan   21     88  Mumbai

# %% [markdown]
# Question 2:

# %%
## Answer

df = pd.DataFrame({
    'Employee': ['Amit', 'Neha', 'Raj', 'Sara', 'John'],
    'Department': ['IT', 'HR', 'IT', 'Finance', 'IT'],
    'Salary': [55000, 45000, 70000, 60000, 80000],
   'Experince': [2, 3, 5, 4, 6]
})
print("DataFrame:")
print(df)

## DataFrames's shape
print("\nShape of DataFrame: ", df.shape)

## Average Salary
print("\nAverage Salary: ", df['Salary'].mean())

## Employee with lowest salary
print("\nEmployee with lowest salary: ", df.loc[df['Salary'].idxmin()]['Employee'])

## Employees from IT Department
print("\nEmployees from IT Department:")
print(df[df['Department']=='IT'])

## Sorting Salary descending
print("\nSorted DataFrame on Salary in descending order:")
df.sort_values('Salary', ascending=False)
# Out:
# DataFrame:
#   Employee Department  Salary  Experince
# 0     Amit         IT   55000          2
# 1     Neha         HR   45000          3
# 2      Raj         IT   70000          5
# 3     Sara    Finance   60000          4
# 4     John         IT   80000          6
#
# Shape of DataFrame:  (5, 4)
#
# Average Salary:  62000.0
#
# Employee with lowest salary:  Neha
#
# Employees from IT Department:
#   Employee Department  Salary  Experince
# 0     Amit         IT   55000          2
# 2      Raj         IT   70000          5
# 4     John         IT   80000          6
#
# Sorted DataFrame on Salary in descending order:
#   Employee Department  Salary  Experince
# 4     John         IT   80000          6
# 2      Raj         IT   70000          5
# 3     Sara    Finance   60000          4
# 0     Amit         IT   55000          2
# 1     Neha         HR   45000          3

# %% [markdown]
# ### Medium

# %% [markdown]
# Question 3:

# %%
## Answer

df = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Chair', 'Table', 'Monitor', 'Desk'],
    'Category': ['Electronics', 'Electronics', 'Furniture', 'Furniture', 'Electronics', 'Furniture'],
    'Sales': [60000, 90000, 20000, 35000, 45000, 25000],
    'Quantity': [3, 6, 5, 3, 5, 4]
})
print("DataFrame:")
print(df)

## Total Sales
print(f"\nTotal Sales: {df['Sales'].sum()}")

## Average Sales
print("\nAverage Sales: ", df['Sales'].mean())

## Total Sales for each category
category_wise_sales = df.groupby('Category')['Sales'].sum()
print("\nTotal sales for each category:")
print(category_wise_sales)

## Product with highest sales
print("\nProduct with highest sales:", df.loc[df['Sales'].idxmax()]['Product'])

## Add new column 'Sales_per_Item
df['Sales_per_Item'] = df['Sales']/df['Quantity']
print('\nModified DataFrame:')
print(df)
# Out:
# DataFrame:
#    Product     Category  Sales  Quantity
# 0   Laptop  Electronics  60000         3
# 1    Phone  Electronics  90000         6
# 2    Chair    Furniture  20000         5
# 3    Table    Furniture  35000         3
# 4  Monitor  Electronics  45000         5
# 5     Desk    Furniture  25000         4
#
# Total Sales: 275000
#
# Average Sales:  45833.333333333336
#
# Total sales for each category:
# Category
# Electronics    195000
# Furniture       80000
# Name: Sales, dtype: int64
#
# Product with highest sales: Phone
#
# Modified DataFrame:
#    Product     Category  Sales  Quantity  Sales_per_Item
# 0   Laptop  Electronics  60000         3    20000.000000
# 1    Phone  Electronics  90000         6    15000.000000
# 2    Chair    Furniture  20000         5     4000.000000
# 3    Table    Furniture  35000         3    11666.666667
# 4  Monitor  Electronics  45000         5     9000.000000
# 5     Desk    Furniture  25000         4     6250.000000

# %% [markdown]
# Question 4:

# %%
## Answer 

df = pd.DataFrame({
    'Name': ['Jack', 'Sara', 'John', 'David', 'Hugh'],
    'Age': [24, None, 27, 25, None],
    'Salary': [50000, 60000, None, 55000, 70000],
    'Department': ['IT', 'HR', 'IT', None, 'IT']
})
print("Original DataFrame:")
print(df)

## Number of missing values in each column
print("\nNumber of missing values in each column:")
print(df.isnull().sum())

## Total number of missing values
print("\nTotal number of missing values:")
print(df.isnull().sum().sum())

## Replacing missing Age values with average age
print("\nModified DataFrame with replaced missing Age values with average age values:")
df['Age'] = df['Age'].fillna(df['Age'].mean())
print(df)

## Replacing missing Salary values with median of salary
print("\nModified DataFrame with replaced missing Salary values with median of Salary:")
df['Salary'] = df['Salary'].fillna(df['Salary'].median())
print(df)

## Replacing missing Department values with "Unknown"
print("\nModified DataFrame with replaced missing Department values with 'Unknown':")
df['Department'] = df['Department'].fillna('Unkown')
print(df)
# Out:
# Original DataFrame:
#     Name   Age   Salary Department
# 0   Jack  24.0  50000.0         IT
# 1   Sara   NaN  60000.0         HR
# 2   John  27.0      NaN         IT
# 3  David  25.0  55000.0        NaN
# 4   Hugh   NaN  70000.0         IT
#
# Number of missing values in each column:
# Name          0
# Age           2
# Salary        1
# Department    1
# dtype: int64
#
# Total number of missing values:
# 4
#
# Modified DataFrame with replaced missing Age values with average age values:
#     Name        Age   Salary Department
# 0   Jack  24.000000  50000.0         IT
# 1   Sara  25.333333  60000.0         HR
# 2   John  27.000000      NaN         IT
# 3  David  25.000000  55000.0        NaN
# 4   Hugh  25.333333  70000.0         IT
#
# Modified DataFrame with replaced missing Salary values with median of Salary:
#     Name        Age   Salary Department
# 0   Jack  24.000000  50000.0         IT
# 1   Sara  25.333333  60000.0         HR
# 2   John  27.000000  57500.0         IT
# ...

# %% [markdown]
# Question 5:

# %%
## Answer

df = pd.DataFrame({
    'Employee': ['A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'Department': ['IT', 'IT', 'HR', 'HR', 'Finance', 'Finance', 'IT'],
    'Salary': [60000, 75000, 45000, 50000, 70000, 80000, 90000],
    'Experience': [2, 5, 3, 4, 6, 8, 7]
})
print("Original DataFrame:")
print(df)

## Average Salary of each Department
print("\nAverage salary of each Department:")
avg_salary = df.groupby('Department')['Salary'].mean()
print(avg_salary)

## Maximum Salary of each Department
print("\nMaximum salary of each Department:")
max_salary = df.groupby('Department')['Salary'].max()
print(max_salary)

## Minimum Salary of each Department
print("\nMinimum salary of each Department:")
min_salary = df.groupby('Department')['Salary'].min()
print(min_salary) 

## Average Experience of each Department
print("\nAverage experience of each Department:")
avg_exp = df.groupby('Department')['Experience'].mean()
print(avg_exp)

## The Department with highest average salary
print("\nDepartment with highest average salary:")
print(df.groupby('Department')['Salary'].mean().idxmax())
print()
## OR
print(avg_salary[avg_salary==avg_salary.max()])
# Out:
# Original DataFrame:
#   Employee Department  Salary  Experience
# 0        A         IT   60000           2
# 1        B         IT   75000           5
# 2        C         HR   45000           3
# 3        D         HR   50000           4
# 4        E    Finance   70000           6
# 5        F    Finance   80000           8
# 6        G         IT   90000           7
#
# Average salary of each Department:
# Department
# Finance    75000.0
# HR         47500.0
# IT         75000.0
# Name: Salary, dtype: float64
#
# Maximum salary of each Department:
# Department
# Finance    80000
# HR         50000
# IT         90000
# Name: Salary, dtype: int64
#
# Minimum salary of each Department:
# Department
# Finance    70000
# HR         45000
# IT         60000
# Name: Salary, dtype: int64
#
# Average experience of each Department:
# Department
# Finance    7.000000
# HR         3.500000
# IT         4.666667
# Name: Experience, dtype: float64
#
# Department with highest average salary:
# ...

# %% [markdown]
# ### Real-World Data Analyst Problems

# %% [markdown]
# Question 6:

# %%
## Answer

## Load CSV into Pandas
df = pd.read_csv('ecommerce_sales.csv')
# print("Original DataFrame:")
# print(df.head())

## Check numner of rows and columns
print(df.shape)

## Check the missing values
print("\nMissing Values in each column:")
print(df.isnull().sum())

## Create a new column Revenue = Quantity*Unit_Price
df['Revenue'] = df['Quantity'] * df['Unit_Price']

## Total Revenue
print("\nTotal Revenue: ", df['Revenue'].sum())

## Top 5 Product categories by Revenue
print("\nTop 5 Product Categories by Revenue:")
product_by_revenue = df.groupby('Product_Category')['Revenue'].sum()
print(product_by_revenue.sort_values(ascending=False).head(5))

## Total revenue by product category
print("\nTotal Revenue by Product Category:")
print(product_by_revenue)

## City Generating the highest revenue
print("\nCity generating highest Revenue:")
revenue_by_city = df.groupby('City')['Revenue'].sum()
print(revenue_by_city[revenue_by_city == revenue_by_city.max()])

## Most commonly used Payment Method
print("\nMost commonly used Payment Method:")
print(df['Payment_Method'].value_counts().idxmax())

## Month with highest Revenue
# print("\nMonth number with highest Revenue:")
# df['Date'] = pd.to_datetime(df['Date'])
# df['Month'] = df['Date'].dt.month
# monthly_revenue = df.groupby('Month')['Revenue'].sum()
# print(monthly_revenue.sort_values(ascending=False).idxmax())

print("\nMonth name with highest Revenue:")
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month_name()
monthly_revenue = df.groupby('Month')['Revenue'].sum()
print(monthly_revenue.sort_values(ascending=False).idxmax())
# Out:
# (5000, 18)
#
# Missing Values in each column:
# Order_ID                    0
# Customer_ID                 0
# Date                        0
# Age                         0
# Gender                      0
# City                        0
# Product_Category            0
# Unit_Price                  0
# Quantity                    0
# Discount_Amount             0
# Total_Amount                0
# Payment_Method              0
# Device_Type                 0
# Session_Duration_Minutes    0
# Pages_Viewed                0
# Is_Returning_Customer       0
# Delivery_Time_Days          0
# Customer_Rating             0
# dtype: int64
#
# Total Revenue:  5039808.59
#
# Top 5 Product Categories by Revenue:
# Product_Category
# Electronics      2391002.99
# Home & Garden     930368.69
# Sports            772840.62
# Fashion           383755.13
# Toys              228410.33
# Name: Revenue, dtype: float64
#
# Total Revenue by Product Category:
# Product_Category
# Beauty            160345.92
# ...
